# %%
from phi.agent import Agent
from phi.model.groq import Groq
from phi.tools.yfinance import YFinanceTools
from phi.tools.duckduckgo import DuckDuckGo
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Web search agent
web_search_agent = Agent(
    name="web_search_agent",
    role="Search the web for information",
    model=Groq(id="llama-3.3-70b-versatile"),
    tools=[DuckDuckGo()],
    instructions=["Always use sources"],
    show_tool_calls=True,
    markdown=True,
)

# %%
# Financial agent
finance_agent = Agent(
    name="Finance agent",
    role="Get financial data",
    model=Groq(id="llama-3.3-70b-versatile"),
    tools=[
        YFinanceTools(
            stock_price=True,
            analyst_recommendations=True,
            stock_fundamentals=True,
            company_news=True,
        )
    ],
    instructions=["Use tables to display data"],
    show_tool_calls=True,
    markdown=True,
)

# %%
# Multi-agent
multi_ai_agent = Agent(
    team=[web_search_agent, finance_agent],
    model=Groq(id="llama-3.3-70b-versatile"),  # <-- THIS WAS MISSING
    instructions=[
        "Always include sources",
        "Use tables to display the data",
    ],
    show_tool_calls=True,
    markdown=True,
)

# %%
multi_ai_agent.print_response(
    "Summarize analyst recommendations and share the latest news for Nvidia",
    stream=True,
)
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Summarize analyst recommendations and share the latest news for Nvidia      │
# │                                                                             │
# ▰▰▰▰▰▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Summarize analyst recommendations and share the latest news for Nvidia      │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 multi_ai_agent.print_response(
#       2     "Summarize analyst recommendations and share the latest news for Nvidia",
#       3     stream=True,
#       4 )
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\phi\agent\agent.py:2825, in Agent.print_response(self, message, messages, stream, markdown, show_message, show_reasoning, show_full_reasoning, console, **kwargs)
#    2822 if render:
#    2823     live_log.update(Group(*panels))
# -> 2825 for resp in self.run(message=message, messages=messages, stream=True, **kwargs):
#    2826     if isinstance(resp, RunResponse) and isinstance(resp.content, str):
#    2827         if resp.event == RunEvent.run_response:
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\phi\agent\agent.py:1805, in Agent._run(self, message, stream, audio, images, videos, messages, stream_intermediate_steps, **kwargs)
#    1803 if self.stream:
#    1804     model_response = ModelResponse(content="")
# -> 1805     for model_response_chunk in self.model.response_stream(messages=messages_for_model):
#    1806         if model_response_chunk.event == ModelResponseEvent.assistant_response.value:
#    1807             if model_response_chunk.content is not None and model_response.content is not None:
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\phi\model\groq\groq.py:733, in Groq.response_stream(self, messages)
#     731 # -*- Generate response
#     732 metrics.response_timer.start()
# --> 733 for response in self.invoke_stream(messages=messages):
#     734     if len(response.choices) > 0:
#     735         metrics.completion_tokens += 1
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\phi\model\groq\groq.py:314, in Groq.invoke_stream(self, messages)
#     304 def invoke_stream(self, messages: List[Message]) -> Iterator[ChatCompletionChunk]:
#     305     """
#     306     Send a streaming chat completion request to the Groq API.
#     307
#    (...)    312         Iterator[ChatCompletionChunk]: An iterator of chat completion chunks.
#     313     """
# --> 314     yield from self.get_client().chat.completions.create(
#     315         model=self.id,
#     316         messages=[self.format_message(m) for m in messages],  # type: ignore
#     317         stream=True,
#     318         **self.request_kwargs,
#     319     )
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\groq\resources\chat\completions.py:466, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     243 def create(
#     244     self,
#     245     *,
#    (...)    302     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     303 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     304     """
#     305     Creates a model response for the given chat conversation.
#     306
#    (...)    464       timeout: Override the client-level default timeout for this request, in seconds
#     465     """
# --> 466     return self._post(
#     467         "/openai/v1/chat/completions",
#     468         body=maybe_transform(
#     469             {
#     470                 "messages": messages,
#     471                 "model": model,
#     472                 "citation_options": citation_options,
#     473                 "compound_custom": compound_custom,
#     474                 "disable_tool_validation": disable_tool_validation,
#     475                 "documents": documents,
#     476                 "exclude_domains": exclude_domains,
#     477                 "frequency_penalty": frequency_penalty,
#     478                 "function_call": function_call,
#     479                 "functions": functions,
#     480                 "include_domains": include_domains,
#     481                 "include_reasoning": include_reasoning,
#     482                 "logit_bias": logit_bias,
#     483                 "logprobs": logprobs,
#     484                 "max_completion_tokens": max_completion_tokens,
#     485                 "max_tokens": max_tokens,
#     486                 "metadata": metadata,
#     487                 "n": n,
#     488                 "parallel_tool_calls": parallel_tool_calls,
#     489                 "presence_penalty": presence_penalty,
#     490                 "reasoning_effort": reasoning_effort,
#     491                 "reasoning_format": reasoning_format,
#     492                 "response_format": response_format,
#     493                 "search_settings": search_settings,
#     494                 "seed": seed,
#     495                 "service_tier": service_tier,
#     496                 "stop": stop,
#     497                 "store": store,
#     498                 "stream": stream,
#     499                 "temperature": temperature,
#     500                 "tool_choice": tool_choice,
#     501                 "tools": tools,
#     502                 "top_logprobs": top_logprobs,
#     503                 "top_p": top_p,
#     504                 "user": user,
#     505             },
#     506             completion_create_params.CompletionCreateParams,
#     507         ),
#     508         options=make_request_options(
#     509             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     510         ),
#     511         cast_to=ChatCompletion,
#     512         stream=stream or False,
#     513         stream_cls=Stream[ChatCompletionChunk],
#     514     )
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\groq\_base_client.py:1284, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1275     warnings.warn(
#    1276         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1277         "Please pass raw bytes via the `content` parameter instead.",
#    1278         DeprecationWarning,
#    1279         stacklevel=2,
#    1280     )
#    1281 opts = FinalRequestOptions.construct(
#    1282     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1283 )
# -> 1284 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Projects\rag_agent\.venv\Lib\site-packages\groq\_base_client.py:1071, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1068             err.response.read()
#    1070         log.debug("Re-raising status error")
# -> 1071         raise self._make_status_error_from_response(err.response) from None
#    1073     break
#    1075 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `llama-3.3-70b-versatile` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'code': 'model_not_found'}}
